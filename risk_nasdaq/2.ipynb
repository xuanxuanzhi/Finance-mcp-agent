# %%
import pandas as pd
df = pd.read_csv('risk_deepseek_cleaned_nasdaq_news_full.csv')

# %%
dff = df.head()

# %%
dff
# Out:
#    Unnamed: 0.1  Unnamed: 0                     Date  \
# 0             0     12043.0  2023-12-16 04:00:00 UTC
# 1             1     12068.0  2023-12-15 00:00:00 UTC
# 2             2     12078.0  2023-12-14 00:00:00 UTC
# 3             3     12097.0  2023-12-13 00:00:00 UTC
# 4             4     12136.0  2023-12-12 00:00:00 UTC
#
#                                        Article_title Stock_symbol  \
# 0   Apple To Halt Sale Of Watch Series 9 And Ultra 2         AAPL
# 1                   Guru Fundamental Report for AAPL         AAPL
# 2  Want to Be in the AI Millionaires Club? 3 Top ...         AAPL
# 3  US STOCKS-Wall St subdued, day after rally on ...         AAPL
# 4  Should You Invest in the iShares Expanded Tech...         AAPL
#
#                                                  Url Publisher  Author  \
# 0  https://www.nasdaq.com/articles/apple-to-halt-...       NaN     NaN
# 1  https://www.nasdaq.com/articles/guru-fundament...       NaN     NaN
# ...

# %%
dff.to_csv("2.csv")
